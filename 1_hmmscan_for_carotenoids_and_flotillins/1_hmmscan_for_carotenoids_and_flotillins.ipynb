# %% [markdown]
# 1. ### Hmmscan for carotenoids and flotillins

# %% [markdown]
# Each subdirectory contains a *run.pbs.sh command that was used to search the 926_gdark_SAGs_DRAM.faa for a specific HMM

# %% [markdown]
# Example command:
# >hmmscan --tblout results.txt NF041003.1.HMM 926_gdark_SAGs_DRAM.faa

# %% [markdown]
# Refer to main manuscript for the provenance of each reference HMM
